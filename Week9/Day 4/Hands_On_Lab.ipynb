# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #8B1E3F 0%, #C44569 55%, #F8A5C2 100%);
#     padding: 50px 35px;
#     border-radius: 22px;
#     color: white;
#     text-align: center;
#     box-shadow: 0 8px 25px rgba(139, 30, 63, 0.25);
#     margin-bottom: 10px;
# ">
# <div style="
#     font-size: 13px;
#     letter-spacing: 3px;
#     text-transform: uppercase;
#     opacity: 0.85;
#     margin-bottom: 12px;
# ">
#     BinX Tech — AI & ML Internship · Week 9 · Day 4
# </div>
#
# <h1 style="
#     font-size: 36px;
#     margin: 0;
#     font-weight: 700;
#     letter-spacing: -0.5px;
# ">
#     Hands-On Lab — Public Deployment
# </h1>
#
# <p style="
#     font-size: 18px;
#     margin-top: 10px;
#     opacity: 0.92;
#     font-weight: 300;
# ">
#     Deploying the ISIC Melanoma Streamlit Application
# </p>
#
# <div style="
#     margin-top: 20px;
#     font-size: 13px;
#     opacity: 0.75;
#     letter-spacing: 1px;
# ">
#     Nadeen Shadeed · BinX Tech AI/ML Internship · 2026
# </div>
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; line-height: 1.8; color: #2d2d2d;">
#
# <div style="
#     background: white;
#     border-radius: 12px;
#     padding: 24px 28px;
#     margin-bottom: 16px;
#     border: 1px solid #f2d4de;
#     font-size: 15px;
#     line-height: 1.85;
# ">
#
# <h3 style="
#     color: #8B1E3F;
#     margin: 0 0 14px 0;
#     font-size: 18px;
# ">
# Lab Objective
# </h3>
#
# In this hands-on lab, I will prepare and deploy the
# <b>ISIC Melanoma Streamlit application</b> as a public web application.
#
# The deployment will reuse the serialized CNN model created during
# <b>Day 1</b> and the Streamlit dashboard implemented during
# <b>Day 3</b>.
#
# The main goal is to move the application from my local development
# environment to a hosted environment and verify that the deployed
# application produces consistent predictions.
#
# </div>
#
# <div style="
#     background: linear-gradient(135deg, #fff5f8, #fdf0f4);
#     border-radius: 12px;
#     padding: 20px 24px;
#     border: 1px solid #f2d4de;
#     font-size: 14.5px;
#     line-height: 1.8;
# ">
#
# <div style="
#     color: #8B1E3F;
#     font-weight: 700;
#     font-size: 12px;
#     letter-spacing: 1.5px;
#     text-transform: uppercase;
#     margin-bottom: 10px;
# ">
# Deployment Goal
# </div>
#
# <b>Local Streamlit App</b>
# → <b>Deployment Configuration</b>
# → <b>Hugging Face Space</b>
# → <b>Build Environment</b>
# → <b>Public Web Application</b>
#
# </div>
# </div>

# %% [markdown]
# <div style="
#     background: #fff5f8;
#     border-left: 5px solid #C44569;
#     border-radius: 12px;
#     padding: 24px 28px;
#     margin: 25px 0;
#     font-family: Georgia, serif;
#     line-height: 1.8;
# ">
#
# <h3 style="
#     color: #8B1E3F;
#     margin-top: 0;
#     margin-bottom: 14px;
#     font-size: 18px;
# ">
# Hands-On Workflow
# </h3>
#
# <div style="
#     background: white;
#     border-radius: 10px;
#     padding: 18px 22px;
#     border: 1px solid #f2d4de;
# ">
#
# <pre style="
#     background: #2d2d2d;
#     color: #f8f8f8;
#     padding: 18px;
#     border-radius: 8px;
#     line-height: 1.7;
#     overflow-x: auto;
# ">
# Local Application
#         ↓
# Check Project Structure
#         ↓
# Create requirements.txt
#         ↓
# Verify Model Path
#         ↓
# Prepare Deployment Files
#         ↓
# Create Hugging Face Space
#         ↓
# Upload / Push Project Files
#         ↓
# Build Application
#         ↓
# Check Deployment Logs
#         ↓
# Open Public URL
#         ↓
# Test Predictions
#         ↓
# Compare Local vs Live Results
# </pre>
#
# </div>
# </div>

# %% [markdown]
# <div style="
#     background: white;
#     border-radius: 12px;
#     padding: 28px 32px;
#     margin: 30px 0 18px 0;
#     border: 1px solid #f2d4de;
#     font-family: Georgia, serif;
#     color: #2d2d2d;
#     line-height: 1.9;
# ">
#
# <h2 style="
#     color: #8B1E3F;
#     margin: 0 0 16px 0;
#     font-size: 24px;
#     font-weight: 700;
# ">
# Step 1 — Verify the Deployment Files
# </h2>
#
# <p style="font-size: 16px; margin: 0;">
# Before preparing the application for public deployment, I first verified
# that the main files required by the Streamlit application are available
# in the expected project locations.
# </p>
#
# <br>
#
# <p style="font-size: 16px; margin: 0;">
# The deployment depends on two important files:
# </p>
#
# <ul style="font-size: 16px; line-height: 1.9;">
#     <li>
#         <b>streamlit_app.py</b> — the Streamlit application that provides
#         the user interface and prediction workflow.
#     </li>
#     <li>
#         <b>melanoma_cnn.keras</b> — the serialized CNN model used to make
#         predictions.
#     </li>
# </ul>
#
# <div style="
#     background: linear-gradient(135deg, #fff5f8, #fdf0f4);
#     border-radius: 10px;
#     padding: 18px 22px;
#     margin-top: 18px;
#     border: 1px solid #f2d4de;
#     font-size: 15px;
# ">
#
# <b style="color: #8B1E3F;">Important:</b>
#
# I will reuse the serialized model created during Day 1 and the Streamlit
# application created during Day 3. I will not create another copy of the
# trained model inside Day 4.
#
# </div>
#
# </div>

# %% [markdown]
# ### Expected Project Structure
#
# The deployment files are organized as follows:
#
# ```text
# Week9/
# │
# ├── Day 1/
# │   └── models/
# │       └── melanoma_cnn.keras
# │
# ├── Day 3/
# │   └── app/
# │       └── streamlit_app.py
# │
# └── Day 4/
#     ├── day4_public_deployment.ipynb
#     └── Hands_On_Lab.ipynb
#
# ```
#
# The Streamlit application from Day 3 will reuse the serialized CNN
# model from Day 1.
#
# This avoids creating duplicate copies of the model and keeps the project
# structure organized.

# %%
from pathlib import Path

# Define the project root directory
project_root = Path.cwd().parent.parent

# Define the paths of the files required for deployment
model_path = (
    project_root
    / "Week9"
    / "Day 1"
    / "models"
    / "melanoma_cnn.keras"
)

app_path = (
    project_root
    / "Week9"
    / "Day 3"
    / "app"
    / "streamlit_app.py"
)

# Check whether each required file exists
print("Model path:")
print(model_path)
print("Model exists:", model_path.exists())

print("\nStreamlit application path:")
print(app_path)
print("Application exists:", app_path.exists())
# Out:
# Model path:
# e:\BinX_AI_ML_Internship\Week9\Day 1\models\melanoma_cnn.keras
# Model exists: True
#
# Streamlit application path:
# e:\BinX_AI_ML_Internship\Week9\Day 3\app\streamlit_app.py
# Application exists: True

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #fff5f8, #fdf0f4);
#     border-radius: 12px;
#     padding: 24px 28px;
#     margin: 22px 0;
#     border: 1px solid #f2d4de;
#     font-family: Georgia, serif;
#     color: #2d2d2d;
#     line-height: 1.9;
# ">
#
# <h3 style="
#     color: #8B1E3F;
#     margin: 0 0 14px 0;
#     font-size: 21px;
# ">
# Verification Result
# </h3>
#
# <p style="font-size: 16px; margin: 0;">
# The required deployment files were successfully located in their expected
# project directories.
# </p>
#
# <ul style="font-size: 16px; line-height: 1.9; margin-top: 12px;">
#     <li>
#         <b>melanoma_cnn.keras</b> was found in the Day 1 model directory.
#     </li>
#     <li>
#         <b>streamlit_app.py</b> was found in the Day 3 application directory.
#     </li>
# </ul>
#
# <p style="font-size: 16px; margin: 12px 0 0 0;">
# The project structure is ready for the next deployment preparation step.
# </p>
#
# </div>

# %% [markdown]
# <div style="
#     background: white;
#     border-radius: 12px;
#     padding: 28px 32px;
#     margin: 30px 0 18px 0;
#     border: 1px solid #f2d4de;
#     font-family: Georgia, serif;
#     color: #2d2d2d;
#     line-height: 1.9;
# ">
#
# <h2 style="
#     color: #8B1E3F;
#     margin: 0 0 16px 0;
#     font-size: 24px;
#     font-weight: 700;
# ">
# Step 2 — Identify Application Dependencies
# </h2>
#
# <p style="font-size: 16px; margin: 0;">
# Before creating <code>requirements.txt</code>, I identified the Python
# libraries required by the deployed Streamlit application.
# </p>
#
# <br>
#
# <p style="font-size: 16px; margin: 0;">
# The application imports the following libraries:
# </p>
#
# <table style="
#     width: 100%;
#     border-collapse: collapse;
#     margin-top: 16px;
#     font-size: 15px;
# ">
#
# <thead>
# <tr style="background: linear-gradient(90deg, #8B1E3F, #C44569);">
#     <th style="padding: 11px 14px; color: white; text-align: left;">
#         Library
#     </th>
#     <th style="padding: 11px 14px; color: white; text-align: left;">
#         Purpose
#     </th>
# </tr>
# </thead>
#
# <tbody>
#
# <tr style="border-bottom: 1px solid #f2d4de;">
#     <td style="padding: 11px 14px;">
#         <b>Streamlit</b>
#     </td>
#     <td style="padding: 11px 14px;">
#         Builds and runs the interactive web application.
#     </td>
# </tr>
#
# <tr style="background: #fdf7f9; border-bottom: 1px solid #f2d4de;">
#     <td style="padding: 11px 14px;">
#         <b>TensorFlow</b>
#     </td>
#     <td style="padding: 11px 14px;">
#         Loads the serialized CNN and performs model inference.
#     </td>
# </tr>
#
# <tr style="border-bottom: 1px solid #f2d4de;">
#     <td style="padding: 11px 14px;">
#         <b>NumPy</b>
#     </td>
#     <td style="padding: 11px 14px;">
#         Converts the uploaded image into an array and prepares the model input.
#     </td>
# </tr>
#
# <tr style="background: #fdf7f9;">
#     <td style="padding: 11px 14px;">
#         <b>Pillow</b>
#     </td>
#     <td style="padding: 11px 14px;">
#         Opens, converts, and resizes uploaded images.
#     </td>
# </tr>
#
# </tbody>
# </table>
#
# <div style="
#     background: linear-gradient(135deg, #fff5f8, #fdf0f4);
#     border-radius: 10px;
#     padding: 18px 22px;
#     margin-top: 20px;
#     border: 1px solid #f2d4de;
#     font-size: 15px;
# ">
#
# <b style="color: #8B1E3F;">Important:</b>
#
# The deployment requirements should describe the dependencies of the
# <b>application being deployed</b>. I do not need to include FastAPI,
# Uvicorn, or <code>python-multipart</code> because those packages belong
# to the Day 2 API and are not required to run the Day 3 Streamlit application.
#
# </div>
#
# </div>

# %%
import tensorflow as tf
import streamlit
import numpy as np
import PIL

print("TensorFlow version:", tf.__version__)
print("Streamlit version:", streamlit.__version__)
print("NumPy version:", np.__version__)
print("Pillow version:", PIL.__version__)
# Out:
# TensorFlow version: 2.21.0
# Streamlit version: 1.63.0
# NumPy version: 2.4.6
# Pillow version: 12.3.0

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #fff5f8, #fdf0f4);
#     border-radius: 12px;
#     padding: 26px 30px;
#     margin: 24px 0;
#     border: 1px solid #f2d4de;
#     font-family: Georgia, serif;
#     color: #2d2d2d;
#     line-height: 1.9;
# ">
#
# <h3 style="
#     color: #8B1E3F;
#     margin: 0 0 16px 0;
#     font-size: 22px;
# ">
# Verified Application Dependencies
# </h3>
#
# <p style="font-size: 16px; margin: 0 0 16px 0;">
# I checked the versions of the libraries used by the Streamlit application
# in my local environment.
# </p>
#
# <table style="
#     width: 100%;
#     border-collapse: collapse;
#     font-size: 15px;
# ">
#
# <thead>
# <tr style="background: linear-gradient(90deg, #8B1E3F, #C44569);">
#     <th style="padding: 11px 14px; color: white; text-align: left;">
#         Package
#     </th>
#     <th style="padding: 11px 14px; color: white; text-align: left;">
#         Verified Version
#     </th>
#     <th style="padding: 11px 14px; color: white; text-align: left;">
#         Application Role
#     </th>
# </tr>
# </thead>
#
# <tbody>
#
# <tr style="border-bottom: 1px solid #f2d4de;">
#     <td style="padding: 11px 14px;"><b>TensorFlow</b></td>
#     <td style="padding: 11px 14px;"><code>2.21.0</code></td>
#     <td style="padding: 11px 14px;">CNN loading and inference</td>
# </tr>
#
# <tr style="background: #fdf7f9; border-bottom: 1px solid #f2d4de;">
#     <td style="padding: 11px 14px;"><b>Streamlit</b></td>
#     <td style="padding: 11px 14px;"><code>1.63.0</code></td>
#     <td style="padding: 11px 14px;">Interactive web interface</td>
# </tr>
#
# <tr style="border-bottom: 1px solid #f2d4de;">
#     <td style="padding: 11px 14px;"><b>NumPy</b></td>
#     <td style="padding: 11px 14px;"><code>2.4.6</code></td>
#     <td style="padding: 11px 14px;">Image arrays and preprocessing</td>
# </tr>
#
# <tr style="background: #fdf7f9;">
#     <td style="padding: 11px 14px;"><b>Pillow</b></td>
#     <td style="padding: 11px 14px;"><code>12.3.0</code></td>
#     <td style="padding: 11px 14px;">Image loading and resizing</td>
# </tr>
#
# </tbody>
# </table>
#
# <div style="
#     background: white;
#     border-radius: 10px;
#     padding: 18px 22px;
#     margin-top: 20px;
#     border: 1px solid #f2d4de;
#     font-size: 15px;
# ">
#
# <b style="color: #8B1E3F;">Deployment Note</b>
#
# <p style="margin: 8px 0 0 0;">
# These verified versions will be used as the starting point for preparing
# the application's <code>requirements.txt</code>. The purpose is to make
# the deployment environment reproducible and reduce differences between
# the local and hosted applications.
# </p>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background: white;
#     border-radius: 12px;
#     padding: 28px 32px;
#     margin: 30px 0 18px 0;
#     border: 1px solid #f2d4de;
#     font-family: Georgia, serif;
#     color: #2d2d2d;
#     line-height: 1.9;
# ">
#
# <h2 style="
#     color: #8B1E3F;
#     margin: 0 0 16px 0;
#     font-size: 24px;
#     font-weight: 700;
# ">
# Step 3 — Create requirements.txt
# </h2>
#
# <p style="font-size: 16px; margin: 0 0 16px 0;">
# The hosting platform will create a fresh Python environment when the
# application is deployed. Therefore, the required Python packages must be
# declared explicitly.
# </p>
#
# <p style="font-size: 16px; margin: 0 0 16px 0;">
# For this Streamlit application, I will create a
# <b>requirements.txt</b> file containing the verified runtime dependencies
# and their versions.
# </p>
#
# <div style="
#     background: #2d2d2d;
#     color: #f8f8f8;
#     border-radius: 10px;
#     padding: 20px 24px;
#     margin: 20px 0;
#     font-family: monospace;
#     font-size: 15px;
#     line-height: 1.8;
# ">
#
# <pre style="margin: 0; color: #f8f8f8;">
# streamlit==1.63.0
# tensorflow==2.21.0
# numpy==2.4.6
# Pillow==12.3.0
# </pre>
#
# </div>
#
# <div style="
#     background: linear-gradient(135deg, #fff5f8, #fdf0f4);
#     border-radius: 10px;
#     padding: 20px 24px;
#     border: 1px solid #f2d4de;
#     font-size: 15px;
# ">
#
# <b style="color: #8B1E3F;">Why these packages?</b>
#
# <ul style="margin: 10px 0 0 0; line-height: 1.9;">
#     <li><b>Streamlit</b> runs the web application.</li>
#     <li><b>TensorFlow</b> loads the serialized CNN and performs inference.</li>
#     <li><b>NumPy</b> prepares image data for the CNN.</li>
#     <li><b>Pillow</b> handles image loading, RGB conversion, and resizing.</li>
# </ul>
#
# <p style="margin: 14px 0 0 0;">
# I am not adding FastAPI, Uvicorn, or <code>python-multipart</code> because
# they are dependencies of the Day 2 API, not of the Streamlit application
# being deployed in this step.
# </p>
#
# </div>
#
# </div>

# %% [markdown]
# **Verify the Streamlit Model Path**

# %%
from pathlib import Path

# Define the project root directory
project_root = Path.cwd().parent.parent

# Recreate the model path used by the Streamlit application
model_path = (
    project_root
    / "Week9"
    / "Day 1"
    / "models"
    / "melanoma_cnn.keras"
)

# Check the model path
print("Project root:")
print(project_root)

print("\nModel path used by the application:")
print(model_path)

print("\nModel exists:", model_path.exists())

if model_path.exists():
    print("Model path verification: PASSED")
else:
    print("Model path verification: FAILED")
# Out:
# Project root:
# e:\BinX_AI_ML_Internship
#
# Model path used by the application:
# e:\BinX_AI_ML_Internship\Week9\Day 1\models\melanoma_cnn.keras
#
# Model exists: True
# Model path verification: PASSED

# %% [markdown]
# <div style="
#     background: white;
#     border-radius: 12px;
#     padding: 28px 32px;
#     margin: 30px 0 18px 0;
#     border: 1px solid #f2d4de;
#     font-family: Georgia, serif;
#     color: #2d2d2d;
#     line-height: 1.9;
# ">
#
# <h2 style="
#     color: #8B1E3F;
#     margin: 0 0 16px 0;
#     font-size: 24px;
#     font-weight: 700;
# ">
# Step 4 — Prepare a Deployment-Friendly File Structure
# </h2>
#
# <p style="font-size: 16px; margin: 0 0 16px 0;">
# The current Streamlit application uses the project structure of my local
# development environment. This structure is useful during development, but
# the hosted application will run inside a different environment.
# </p>
#
# <p style="font-size: 16px; margin: 0 0 16px 0;">
# For deployment, I will use a simpler structure in which the application
# file and the serialized model are located in the same deployment directory.
# This makes the model path portable and independent of my personal computer.
# </p>
#
# <div style="
#     background: #2d2d2d;
#     color: #f8f8f8;
#     border-radius: 10px;
#     padding: 20px 24px;
#     margin: 20px 0;
#     font-family: monospace;
#     font-size: 15px;
#     line-height: 1.8;
# ">
#
# <pre style="margin: 0; color: #f8f8f8;">
# melanoma-streamlit/
# │
# ├── app.py
# ├── requirements.txt
# └── melanoma_cnn.keras
# </pre>
#
# </div>
#
# <div style="
#     background: linear-gradient(135deg, #fff5f8, #fdf0f4);
#     border-radius: 10px;
#     padding: 20px 24px;
#     border: 1px solid #f2d4de;
#     font-size: 15px;
# ">
#
# <b style="color: #8B1E3F;">Why simplify the structure?</b>
#
# <p style="margin: 10px 0 0 0;">
# The hosted application should not depend on paths such as
# <code>E:\BinX_AI_ML_Internship\...</code>. These paths exist only on my
# local computer.
# </p>
#
# <p style="margin: 10px 0 0 0;">
# Instead, the application will use a path relative to its own location.
# This allows the same application structure to work in the hosted
# environment.
# </p>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background: white;
#     border-radius: 12px;
#     padding: 28px 32px;
#     margin: 30px 0 18px 0;
#     border: 1px solid #f2d4de;
#     font-family: Georgia, serif;
#     color: #2d2d2d;
#     line-height: 1.9;
# ">
#
# <h2 style="
#     color: #8B1E3F;
#     margin: 0 0 16px 0;
#     font-size: 24px;
#     font-weight: 700;
# ">
# Step 5 — Create the Deployment Application
# </h2>
#
# <p style="font-size: 16px; margin: 0 0 16px 0;">
# For the hosted application, I will create a deployment version of the
# Streamlit application named <b>app.py</b>.
# </p>
#
# <p style="font-size: 16px; margin: 0 0 16px 0;">
# The main change is the model path. Instead of referencing the original
# local project structure, the application will locate the serialized model
# relative to its own file.
# </p>
#
# <div style="
#     background: #2d2d2d;
#     color: #f8f8f8;
#     border-radius: 10px;
#     padding: 20px 24px;
#     margin: 20px 0;
#     font-family: monospace;
#     font-size: 15px;
#     line-height: 1.8;
# ">
#
# <pre style="margin: 0; color: #f8f8f8;">
# from pathlib import Path
#
# MODEL_PATH = Path(__file__).parent / "melanoma_cnn.keras"
# </pre>
#
# </div>
#
# <p style="font-size: 16px; margin: 16px 0 0 0;">
# This means that when <code>app.py</code> runs, it looks for
# <code>melanoma_cnn.keras</code> in the same directory.
# </p>
#
# <div style="
#     background: linear-gradient(135deg, #fff5f8, #fdf0f4);
#     border-radius: 10px;
#     padding: 20px 24px;
#     margin-top: 20px;
#     border: 1px solid #f2d4de;
#     font-size: 15px;
# ">
#
# <b style="color: #8B1E3F;">Deployment Structure</b>
#
# <div style="
#     background: white;
#     border-radius: 8px;
#     padding: 14px 18px;
#     margin-top: 12px;
#     font-family: monospace;
# ">
#
# app.py<br>
# ↓<br>
# melanoma_cnn.keras
#
# </div>
#
# <p style="margin: 14px 0 0 0;">
# The prediction logic, preprocessing steps, classification threshold, and
# user interface remain consistent with the application tested locally
# during Day 3.
# </p>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background: white;
#     border-radius: 12px;
#     padding: 28px 32px;
#     margin: 30px 0 18px 0;
#     border: 1px solid #f2d4de;
#     font-family: Georgia, serif;
#     color: #2d2d2d;
#     line-height: 1.9;
# ">
#
# <h2 style="
#     color: #8B1E3F;
#     margin: 0 0 16px 0;
#     font-size: 24px;
#     font-weight: 700;
# ">
# Step 6 — Create the Deployment app.py
# </h2>
#
# <p style="font-size: 16px; margin: 0 0 16px 0;">
# I will create a separate <b>app.py</b> for deployment by reusing the
# Streamlit application tested successfully during Day 3.
# </p>
#
# <p style="font-size: 16px; margin: 0 0 16px 0;">
# The original <code>Day 3/app/streamlit_app.py</code> will remain unchanged.
# This keeps the tested development version separate from the deployment
# version.
# </p>
#
# <div style="
#     background: linear-gradient(135deg, #fff5f8, #fdf0f4);
#     border-radius: 10px;
#     padding: 20px 24px;
#     border: 1px solid #f2d4de;
#     font-size: 15px;
# ">
#
# <b style="color: #8B1E3F;">Deployment Change</b>
#
# <p style="margin: 10px 0 0 0;">
# The deployment version will use:
# </p>
#
# <div style="
#     background: white;
#     border-radius: 8px;
#     padding: 14px 18px;
#     margin-top: 10px;
#     font-family: monospace;
# ">
#
# <code>MODEL_PATH = Path(__file__).parent / "melanoma_cnn.keras"</code>
#
# </div>
#
# <p style="margin: 12px 0 0 0;">
# All other prediction logic remains consistent with the tested Day 3
# application.
# </p>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background: white;
#     border-radius: 12px;
#     padding: 28px 32px;
#     margin: 30px 0 18px 0;
#     border: 1px solid #f2d4de;
#     font-family: Georgia, serif;
#     color: #2d2d2d;
#     line-height: 1.9;
# ">
#
# <h2 style="
#     color: #8B1E3F;
#     margin: 0 0 16px 0;
#     font-size: 24px;
#     font-weight: 700;
# ">
# Step 7 — Copy the Serialized Model
# </h2>
#
# <p style="font-size: 16px; margin: 0 0 16px 0;">
# The deployment application requires the serialized CNN model to perform
# inference. I will therefore copy the model created during Day 1 into the
# deployment directory.
# </p>
#
# <div style="
#     background: #2d2d2d;
#     color: #f8f8f8;
#     border-radius: 10px;
#     padding: 20px 24px;
#     margin: 20px 0;
#     font-family: monospace;
#     font-size: 15px;
#     line-height: 1.8;
# ">
#
# <pre style="margin: 0; color: #f8f8f8;">
# Source:
# Week9/Day 1/models/melanoma_cnn.keras
#
#         ↓
#
# Deployment:
# Week9/Day 4/deployment/melanoma_cnn.keras
# </pre>
#
# </div>
#
# <div style="
#     background: linear-gradient(135deg, #fff5f8, #fdf0f4);
#     border-radius: 10px;
#     padding: 20px 24px;
#     border: 1px solid #f2d4de;
#     font-size: 15px;
# ">
#
# <b style="color: #8B1E3F;">Important</b>
#
# <p style="margin: 10px 0 0 0;">
# This is a copy of the already trained and serialized model. The model is
# not retrained or modified during deployment preparation.
# </p>
#
# <p style="margin: 10px 0 0 0;">
# Keeping the model together with <code>app.py</code> allows the deployment
# application to load it using a portable relative path.
# </p>
#
# </div>
#
# </div>

# %% [markdown]
# **Verify Deployment Files**

# %%
from pathlib import Path

# Find the Day 4 directory from the current working directory
current_path = Path.cwd()

day4_dir = current_path

while day4_dir.name != "Day 4":
    day4_dir = day4_dir.parent

# Define the deployment directory
deployment_dir = day4_dir / "deployment"

# Define the required deployment files
app_path = deployment_dir / "app.py"
model_path = deployment_dir / "melanoma_cnn.keras"
requirements_path = day4_dir / "requirements.txt"

# Print the paths
print("Day 4 directory:")
print(day4_dir)

print("\nDeployment directory:")
print(deployment_dir)

print("\nApplication file:")
print(app_path)
print("Exists:", app_path.exists())

print("\nSerialized model:")
print(model_path)
print("Exists:", model_path.exists())

print("\nRequirements file:")
print(requirements_path)
print("Exists:", requirements_path.exists())

# Final verification
all_files_exist = (
    app_path.exists()
    and model_path.exists()
    and requirements_path.exists()
)

print(
    "\nDeployment preparation:",
    "PASSED" if all_files_exist else "FAILED"
)
# Out:
# Day 4 directory:
# e:\BinX_AI_ML_Internship\Week9\Day 4
#
# Deployment directory:
# e:\BinX_AI_ML_Internship\Week9\Day 4\deployment
#
# Application file:
# e:\BinX_AI_ML_Internship\Week9\Day 4\deployment\app.py
# Exists: True
#
# Serialized model:
# e:\BinX_AI_ML_Internship\Week9\Day 4\deployment\melanoma_cnn.keras
# Exists: True
#
# Requirements file:
# e:\BinX_AI_ML_Internship\Week9\Day 4\requirements.txt
# Exists: True
#
# Deployment preparation: PASSED

# %% [markdown]
# <div style="
#     background: white;
#     border-radius: 12px;
#     padding: 28px 32px;
#     margin: 30px 0 18px 0;
#     border: 1px solid #f2d4de;
#     font-family: Georgia, serif;
#     color: #2d2d2d;
#     line-height: 1.9;
# ">
#
# <h2 style="
#     color: #8B1E3F;
#     margin: 0 0 16px 0;
#     font-size: 24px;
#     font-weight: 700;
# ">
# Step 8 — Verify the Deployment Application Locally
# </h2>
#
# <p style="font-size: 16px; margin: 0 0 16px 0;">
# Before uploading the application to a public hosting platform, I will
# test the deployment version locally.
# </p>
#
# <p style="font-size: 16px; margin: 0 0 16px 0;">
# This verifies that the deployment-specific file structure and relative
# model path work correctly before introducing the additional variables of
# a cloud environment.
# </p>
#
# <div style="
#     background: linear-gradient(135deg, #fff5f8, #fdf0f4);
#     border-radius: 10px;
#     padding: 20px 24px;
#     border: 1px solid #f2d4de;
#     font-size: 15px;
# ">
#
# <b style="color: #8B1E3F;">What I am verifying</b>
#
# <ul style="margin: 10px 0 0 0; line-height: 1.9;">
#     <li>The Streamlit application starts successfully.</li>
#     <li>The serialized CNN model can be loaded.</li>
#     <li>The new relative model path works correctly.</li>
#     <li>The application interface is available for image prediction.</li>
# </ul>
#
# </div>
#
# <div style="
#     background: white;
#     border-radius: 10px;
#     padding: 18px 22px;
#     margin-top: 18px;
#     border: 1px solid #f2d4de;
#     font-size: 15px;
# ">
#
# <b style="color: #8B1E3F;">Important:</b>
#
# The application will be tested using the deployment copy, not the original
# Day 3 application. This ensures that the exact files intended for public
# deployment are validated before upload.
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #fff5f8, #fdf0f4);
#     border-radius: 12px;
#     padding: 26px 30px;
#     margin: 24px 0;
#     border: 1px solid #f2d4de;
#     font-family: Georgia, serif;
#     color: #2d2d2d;
#     line-height: 1.9;
# ">
#
# <h3 style="
#     color: #8B1E3F;
#     margin: 0 0 16px 0;
#     font-size: 22px;
# ">
# Local Deployment Verification — PASSED
# </h3>
#
# <p style="font-size: 16px; margin: 0 0 14px 0;">
# The deployment copy of the Streamlit application started successfully
# and loaded the serialized CNN model from its deployment directory.
# </p>
#
# ![alt text](image.png)
#
# ![alt text](image-1.png)
#
# <table style="
#     width: 100%;
#     border-collapse: collapse;
#     font-size: 15px;
#     margin-top: 14px;
# ">
#
# <thead>
# <tr style="background: linear-gradient(90deg, #8B1E3F, #C44569);">
#     <th style="padding: 11px 14px; color: white; text-align: left;">
#         Test
#     </th>
#     <th style="padding: 11px 14px; color: white; text-align: left;">
#         Result
#     </th>
# </tr>
# </thead>
#
# <tbody>
#
# <tr style="border-bottom: 1px solid #f2d4de;">
#     <td style="padding: 11px 14px;">
#         Application startup
#     </td>
#     <td style="padding: 11px 14px;">
#         <b>Successful</b>
#     </td>
# </tr>
#
# <tr style="background: #fdf7f9; border-bottom: 1px solid #f2d4de;">
#     <td style="padding: 11px 14px;">
#         Model loading
#     </td>
#     <td style="padding: 11px 14px;">
#         <b>Successful</b>
#     </td>
# </tr>
#
# <tr style="border-bottom: 1px solid #f2d4de;">
#     <td style="padding: 11px 14px;">
#         Test image
#     </td>
#     <td style="padding: 11px 14px;">
#         <b>3.jpg</b>
#     </td>
# </tr>
#
# <tr style="background: #fdf7f9;">
#     <td style="padding: 11px 14px;">
#         Prediction
#     </td>
#     <td style="padding: 11px 14px;">
#         <b>Benign — 61.05%</b>
#     </td>
# </tr>
#
# </tbody>
# </table>
#
# <div style="
#     background: white;
#     border-radius: 10px;
#     padding: 18px 22px;
#     margin-top: 20px;
#     border: 1px solid #f2d4de;
#     font-size: 15px;
# ">
#
# <b style="color: #8B1E3F;">Conclusion</b>
#
# <p style="margin: 8px 0 0 0;">
# The deployment version produces the same prediction as the previously
# tested Day 3 application for the same input image. The deployment-specific
# model path therefore works correctly in the local environment.
# </p>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background: white;
#     border-radius: 12px;
#     padding: 28px 32px;
#     margin: 30px 0 18px 0;
#     border: 1px solid #f2d4de;
#     font-family: Georgia, serif;
#     color: #2d2d2d;
#     line-height: 1.9;
# ">
#
# <h2 style="
#     color: #8B1E3F;
#     margin: 0 0 16px 0;
#     font-size: 24px;
#     font-weight: 700;
# ">
# Step 9 — Hugging Face Spaces
# </h2>
#
# <p style="font-size: 16px; margin: 0 0 16px 0;">
# For the public deployment, I will use
# <b>Hugging Face Spaces</b> as the hosting platform for my Streamlit
# application.
# </p>
#
# <p style="font-size: 16px; margin: 0 0 16px 0;">
# A Space provides a hosted environment where the application files are
# stored in a Git-based repository and the application can be built and
# served as a public web application.
# </p>
#
# <div style="
#     background: linear-gradient(135deg, #fff5f8, #fdf0f4);
#     border-radius: 10px;
#     padding: 20px 24px;
#     border: 1px solid #f2d4de;
#     font-size: 15px;
# ">
#
# <b style="color: #8B1E3F;">Current Hugging Face Configuration</b>
#
# <p style="margin: 10px 0 0 0;">
# The current Hugging Face documentation recommends using the
# <b>Docker SDK with the Streamlit template</b> for new Streamlit Spaces.
# This differs from older tutorials that directly selected Streamlit as the
# Space SDK.
# </p>
#
# </div>
#
# <div style="
#     background: #2d2d2d;
#     color: #f8f8f8;
#     border-radius: 10px;
#     padding: 20px 24px;
#     margin-top: 20px;
#     font-family: monospace;
#     font-size: 15px;
#     line-height: 1.8;
# ">
#
# <pre style="margin: 0; color: #f8f8f8;">
# Local Project
#       ↓
# Hugging Face Space
#       ↓
# Build Environment
#       ↓
# Install Dependencies
#       ↓
# Start Application
#       ↓
# Public Web Application
# </pre>
#
# </div>
#
# <div style="
#     background: linear-gradient(135deg, #fff5f8, #fdf0f4);
#     border-radius: 10px;
#     padding: 20px 24px;
#     margin-top: 20px;
#     border: 1px solid #f2d4de;
#     font-size: 15px;
# ">
#
# <b style="color: #8B1E3F;">Important</b>
#
# <p style="margin: 10px 0 0 0;">
# The Space will contain the files required to build and run the application,
# while the model remains the same serialized CNN already validated locally.
# </p>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background: white;
#     border-radius: 12px;
#     padding: 28px 32px;
#     margin: 30px 0 18px 0;
#     border: 1px solid #f2d4de;
#     font-family: Georgia, serif;
#     color: #2d2d2d;
#     line-height: 1.9;
# ">
#
# <h2 style="
#     color: #8B1E3F;
#     margin: 0 0 16px 0;
#     font-size: 24px;
#     font-weight: 700;
# ">
# Step 10 — Prepare the Hugging Face Space Files
# </h2>
#
# <p style="font-size: 16px; margin: 0 0 16px 0;">
# The Hugging Face Space will have its own repository. The files required
# to run the application should be available directly from the repository
# root.
# </p>
#
# <div style="
#     background: #2d2d2d;
#     color: #f8f8f8;
#     border-radius: 10px;
#     padding: 20px 24px;
#     margin: 20px 0;
#     font-family: monospace;
#     font-size: 15px;
#     line-height: 1.8;
# ">
#
# <pre style="margin: 0; color: #f8f8f8;">
# Hugging Face Space
# │
# ├── app.py
# ├── requirements.txt
# └── melanoma_cnn.keras
# </pre>
#
# </div>
#
# <div style="
#     background: linear-gradient(135deg, #fff5f8, #fdf0f4);
#     border-radius: 10px;
#     padding: 20px 24px;
#     border: 1px solid #f2d4de;
#     font-size: 15px;
# ">
#
# <b style="color: #8B1E3F;">Why is the structure different?</b>
#
# <p style="margin: 10px 0 0 0;">
# The <code>deployment</code> folder was used as a local preparation
# directory. When the application is uploaded to the Space, its required
# files will be placed directly in the Space repository.
# </p>
#
# <p style="margin: 10px 0 0 0;">
# This also matches the deployment application's relative model path:
# </p>
#
# <div style="
#     background: white;
#     border-radius: 8px;
#     padding: 12px 16px;
#     margin-top: 10px;
#     font-family: monospace;
# ">
#
# <code>Path(__file__).parent / "melanoma_cnn.keras"</code>
#
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #fff5f8, #fdf0f4);
#     border-radius: 12px;
#     padding: 24px 28px;
#     margin: 25px 0;
#     border: 1px solid #f2d4de;
#     font-family: Georgia, serif;
#     color: #2d2d2d;
#     line-height: 1.9;
#     font-size: 16px;
# ">
#
# <h2 style="
#     color: #8B1E3F;
#     margin: 0 0 16px 0;
#     font-size: 24px;
# ">
# Hugging Face Platform Check
# </h2>
#
# <p>
# I initially considered <b>Hugging Face Spaces</b> as the hosting platform
# for this project because it is commonly used for Machine Learning demos.
# However, the available Space creation options depend on the current
# account plan.
# </p>
#
# <p>
# For this account, the current creation page indicates that
# <b>Gradio and Docker Spaces require a paid plan</b>, while
# <b>Static Spaces are available for free</b>.
# </p>
#
# <p>
# A Static Space is not suitable for this project because the application
# needs a <b>Python runtime</b> to execute Streamlit, TensorFlow, NumPy,
# Pillow, and the serialized <code>melanoma_cnn.keras</code> model.
# A static frontend cannot directly perform this server-side CNN inference.
# </p>
#
# <p>
# Therefore, I did not continue with a Static Space. Instead, I selected
# a hosting platform that can run the existing <b>Streamlit application</b>
# with its Python dependencies without requiring a paid hosting plan.
# </p>
#
# <div style="
#     background: white;
#     border-left: 5px solid #C44569;
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin-top: 18px;
# ">
#
# <b style="color: #8B1E3F;">Decision</b>
#
# <br>
#
# Hugging Face Spaces was evaluated but not used for the final deployment
# because the available free option was Static hosting, which does not
# match the runtime requirements of this Streamlit + TensorFlow application.
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background: white;
#     border-radius: 12px;
#     padding: 28px 32px;
#     margin: 30px 0 18px 0;
#     border: 1px solid #f2d4de;
#     font-family: Georgia, serif;
#     color: #2d2d2d;
#     line-height: 1.9;
#     font-size: 16px;
# ">
#
# <h2 style="
#     color: #8B1E3F;
#     margin: 0 0 16px 0;
#     font-size: 24px;
# ">
# Step 12 — Prepare the GitHub Deployment Files
# </h2>
#
# <p>
# Streamlit Community Cloud deploys applications directly from
# a <b>GitHub repository</b>. Therefore, the deployment-ready files
# must be available in the repository before starting the deployment.
# </p>
#
# <p>
# For this project, the deployment package contains three essential files:
# </p>
#
# <div style="
#     background: #2d2d2d;
#     color: #f8f8f8;
#     border-radius: 10px;
#     padding: 20px 24px;
#     margin: 20px 0;
#     font-family: monospace;
#     font-size: 15px;
#     line-height: 1.8;
# ">
#
# <pre style="margin: 0; color: #f8f8f8;">
# deployment/
# │
# ├── app.py
# ├── melanoma_cnn.keras
# └── requirements.txt
# </pre>
#
# </div>
#
# <div style="
#     background: linear-gradient(135deg, #fff5f8, #fdf0f4);
#     border-radius: 10px;
#     padding: 20px 24px;
#     border: 1px solid #f2d4de;
# ">
#
# <b style="color: #8B1E3F;">Purpose of each file</b>
#
# <ul style="margin-top: 12px;">
#     <li>
#         <b>app.py</b> — contains the Streamlit application and prediction logic.
#     </li>
#     <li>
#         <b>melanoma_cnn.keras</b> — contains the serialized trained CNN model.
#     </li>
#     <li>
#         <b>requirements.txt</b> — specifies the Python dependencies required
#         to run the application.
#     </li>
# </ul>
#
# </div>
#
# <p style="margin-top: 18px;">
# The model and application code remain unchanged. The main deployment task
# is to make these files available in a GitHub repository so that the hosting
# platform can install the dependencies, load the model, start the Streamlit
# application, and expose it through a public URL.
# </p>
#
# </div>

# %% [markdown]
# <div style="
#     background: white;
#     border-radius: 12px;
#     padding: 28px 32px;
#     margin: 30px 0 18px 0;
#     border: 1px solid #f2d4de;
#     font-family: Georgia, serif;
#     color: #2d2d2d;
#     line-height: 1.9;
#     font-size: 16px;
# ">
#
# <h2 style="
#     color: #8B1E3F;
#     margin: 0 0 16px 0;
#     font-size: 24px;
# ">
# Step 13 — Check Git Status
# </h2>
#
# <p>
# Before committing the deployment files, I will check the current Git
# status of the repository. This allows me to identify which files are
# new, modified, or untracked before adding anything to the commit.
# </p>
#
# <p>
# This is an important step because I want to commit only the files related
# to the deployment preparation and avoid accidentally including unrelated
# changes.
# </p>
#
# </div>

# %% [markdown]
# <div style="
#     background: white;
#     border-radius: 12px;
#     padding: 28px 32px;
#     margin: 30px 0 18px 0;
#     border: 1px solid #f2d4de;
#     font-family: Georgia, serif;
#     color: #2d2d2d;
#     line-height: 1.9;
#     font-size: 16px;
# ">
#
# <h2 style="
#     color: #8B1E3F;
#     margin: 0 0 16px 0;
#     font-size: 24px;
# ">
# Step 14 — Final Live Deployment Verification
# </h2>
#
# <p>
# I tested the publicly deployed Streamlit application using the same
# test images that were used during local testing.
# </p>
#
# <p>
# The live predictions and confidence values matched the local results
# exactly for all three test cases.
# </p>
#
# <table style="width:100%; border-collapse:collapse; margin-top:18px;">
# <tr style="background:#f8e8ee;">
#     <th style="padding:10px; border:1px solid #e5c5d0;">Image</th>
#     <th style="padding:10px; border:1px solid #e5c5d0;">Prediction</th>
#     <th style="padding:10px; border:1px solid #e5c5d0;">Confidence</th>
#     <th style="padding:10px; border:1px solid #e5c5d0;">Local vs Live</th>
# </tr>
# <tr>
#     <td style="padding:10px; border:1px solid #e5c5d0;">3.jpg</td>
#     <td style="padding:10px; border:1px solid #e5c5d0;">Benign</td>
#     <td style="padding:10px; border:1px solid #e5c5d0;">61.05%</td>
#     <td style="padding:10px; border:1px solid #e5c5d0;">Match ✓</td>
# </tr>
# <tr>
#     <td style="padding:10px; border:1px solid #e5c5d0;">22.jpg</td>
#     <td style="padding:10px; border:1px solid #e5c5d0;">Benign</td>
#     <td style="padding:10px; border:1px solid #e5c5d0;">91.12%</td>
#     <td style="padding:10px; border:1px solid #e5c5d0;">Match ✓</td>
# </tr>
# <tr>
#     <td style="padding:10px; border:1px solid #e5c5d0;">64.jpg</td>
#     <td style="padding:10px; border:1px solid #e5c5d0;">Malignant</td>
#     <td style="padding:10px; border:1px solid #e5c5d0;">99.91%</td>
#     <td style="padding:10px; border:1px solid #e5c5d0;">Match ✓</td>
# </tr>
# </table>
#
# <p style="
#     margin-top:18px;
#     font-weight:bold;
#     color:#8B1E3F;
# ">
# Live Deployment Verification: PASSED — 3/3 test cases matched the local application.
# </p>
#
# </div>

# %% [markdown]
# <div style="
#     background: white;
#     border-radius: 12px;
#     padding: 28px 32px;
#     margin: 30px 0 18px 0;
#     border: 1px solid #f2d4de;
#     font-family: Georgia, serif;
#     color: #2d2d2d;
#     line-height: 1.9;
#     font-size: 16px;
# ">
#
# <h2 style="
#     color: #8B1E3F;
#     margin: 0 0 16px 0;
#     font-size: 24px;
# ">
# Step 15 — Public Application URL
# </h2>
#
# <p>
# The Streamlit application was successfully deployed as a public web application.
# </p>
#
# <p>
# The deployed application is available at:
# </p>
#
# <p style="
#     background:#f8e8ee;
#     padding:14px 18px;
#     border-radius:8px;
#     word-break:break-all;
# ">
# <a href="https://binxaimlinternship-ahm9zn2cc7ebk8gzw7fzhh.streamlit.app/" target="_blank">
# https://binxaimlinternship-ahm9zn2cc7ebk8gzw7fzhh.streamlit.app/
# </a>
# </p>
#
# <p>
# This URL can be used to access and test the deployed Streamlit application
# without running it locally.
# </p>
#
# </div>

# %% [markdown]
# <div style="
#     background: white;
#     border-radius: 12px;
#     padding: 28px 32px;
#     margin: 30px 0 18px 0;
#     border: 1px solid #f2d4de;
#     font-family: Georgia, serif;
#     color: #2d2d2d;
#     line-height: 1.9;
#     font-size: 16px;
# ">
#
# <h2 style="
#     color: #8B1E3F;
#     margin: 0 0 16px 0;
#     font-size: 24px;
# ">
# Step 16 — Deployment Completion
# </h2>
#
# <p>
# The Streamlit application was successfully deployed to a public cloud
# environment and tested using multiple image inputs.
# </p>
#
# <p>
# The live application produced the same predictions and confidence values
# as the local application for all three test cases.
# </p>
#
# <p>
# The deployment process included dependency configuration, model packaging,
# application deployment, live testing, and verification of local-versus-live
# results.
# </p>
#
# <p style="
#     margin-top:18px;
#     font-weight:bold;
#     color:#8B1E3F;
# ">
# Public Deployment: PASSED ✓
# </p>
#
# </div>
